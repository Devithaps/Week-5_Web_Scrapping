# %%
pip install beautifulsoup4 requests

# %%
import csv
import requests
from bs4 import BeautifulSoup

# Define URL and headers to mimic a browser request
URL = "https://realpython.github.io/fake-jobs/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
}


def scrape_jobs():
    # Fetch webpage content
    response = requests.get(URL, headers=HEADERS)
    if response.status_code != 200:
        print(f"Failed to fetch page. Status code: {response.status_code}")
        return

    # Parse HTML data
    soup = BeautifulSoup(response.text, "html.parser")

    # Find all individual job posting container cards
    job_cards = soup.find_all("div", class_="card-content")

    # Open CSV file to write data
    with open("fake_jobs.csv", mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)

        # Write header row
        writer.writerow(["Job Title", "Company"])

        # Extract data points from each card
        for card in job_cards:
            title_element = card.find("h2", class_="title")
            company_element = card.find("h3", class_="company")

            # Clean text by removing trailing white spaces
            title = title_element.text.strip() if title_element else "N/A"
            company = (
                company_element.text.strip() if company_element else "N/A"
            )

            # Write row data to CSV
            writer.writerow([title, company])

    print("Scraping completed successfully. Data saved to 'fake_jobs.csv'.")


if __name__ == "__main__":
    scrape_jobs()
# Out:
# Scraping completed successfully. Data saved to 'fake_jobs.csv'.
